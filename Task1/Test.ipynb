# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
import os

# %%
# (Opcional) si no está en el PATH:
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/ts/tesseract.exe"
os.environ["TESSDATA_PREFIX"] = r"C:\Program Files\ts\tessdata"

# %%
# Ruta local de la imagen
image_path = "captura1.png"  # reemplaza por el nombre de tu imagen

# Cargar imagen
image = Image.open(image_path)

# %%
# Mostrar imagen (opcional)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
texto = pytesseract.image_to_string(image, lang="eng")

# %%
# Mostrar resultado
print("Texto detectado:")
print(texto)
# Out:
# Texto detectado:
# (S/kWh). El costo dependerd de dos factores: si ese consumo fue
# durante el periodo base, el intermedio o el punta y también varia segun
# el cargo fijo que hace la CFE por sus costos de operaci6n.
#
# Demanda en kW: es la demanda maxima que registr6 CFE en cada
# periodo, el pico mds alto del mes. Sin embargo, el cobro en pesos por
# kilowatt (S/kW) Gnicamente considera el pico mds alto o la demanda
# maxima registrada durante el periodo punta. Esto se cobra en el recibo
# como “Capacidad”.
#
# Grafica de consumo histdrico: en algunos recibos, se proporciona una
# visualizacién del consumo en periodos anteriores, lo que ayuda a
# identificar tendencias y evaluar el impacto de medidas de eficiencia
#
# energética. x
